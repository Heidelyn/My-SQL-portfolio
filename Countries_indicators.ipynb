# %% [markdown]
# In this notebook, I had been working with the countries database containing information about the most populous world cities as well as country-level economic data, population data, and geographic data. This countries database also contains information on languages spoken in each country.
#
# The database was explored by reviewing fertility rate, unemployment rate, population,  GDP, inflation rate, languages, country size, largest capital cities, etc.

# %% [markdown]
# Highest inflation rates for Countries in 2010 and 2015.

# %%
SELECT c.code AS country_code, local_name, year, inflation_rate
FROM world.countries AS c
  INNER JOIN world.economies  AS  e
    ON c.code = e.code
    WHERE inflation_rate IS NOT NULL
    ORDER BY inflation_rate desc;
# Out:
#     country_code                        local_name  year  inflation_rate
# 0            VEN                         Venezuela  2015         121.738
# 1            UKR                          Ukrajina  2015          48.684
# 2            YEM                          Al-Yaman  2015          39.403
# 3            VEN                         Venezuela  2010          28.187
# 4            COD  Republique Democratique du Congo  2010          23.464
# ..           ...                               ...   ...             ...
# 363          QAT                             Qatar  2010          -2.406
# 364          ZWE                          Zimbabwe  2015          -2.410
# 365          NER                             Niger  2010          -2.786
# 366          LBN                            Lubnan  2015          -3.749
# 367          KIR                          Kiribati  2010          -3.900
#
# [368 rows x 4 columns]

# %% [markdown]
# Inflation rate for 2010 and 2015

# %% [markdown]
# Fertility rate for 2010 and 2015.

# %%
SELECT code,local_name,region, year, fertility_rate
  FROM world.countries AS c
    INNER JOIN  world.populations  AS  p
      ON c.code = p.country_code;
# Out:
#     code             local_name                     region  year  \
# 0    ABW                  Aruba                  Caribbean  2010
# 1    ABW                  Aruba                  Caribbean  2015
# 2    AFG  Afganistan/Afqanestan  Southern and Central Asia  2010
# 3    AFG  Afganistan/Afqanestan  Southern and Central Asia  2015
# 4    AGO                 Angola             Central Africa  2010
# ..   ...                    ...                        ...   ...
# 407  ZAF           South Africa            Southern Africa  2015
# 408  ZMB                 Zambia             Eastern Africa  2010
# 409  ZMB                 Zambia             Eastern Africa  2015
# 410  ZWE               Zimbabwe             Eastern Africa  2010
# 411  ZWE               Zimbabwe             Eastern Africa  2015
#
#      fertility_rate
# 0             1.704
# 1             1.647
# 2             5.746
# 3             4.653
# 4             6.416
# ..              ...
# 407           2.339
# 408           5.687
# 409           5.284
# 410           4.048
# 411           3.856
#
# [412 rows x 5 columns]

# %% [markdown]
# Fertility rate and the unemployment rate for both 2010 and 2015, for each country.

# %%
SELECT c.code, local_name, region, e.year, fertility_rate, unemployment_rate
  FROM world.countries AS c
  INNER JOIN world.populations AS p
    ON c.code = p.country_code
  INNER JOIN world.economies AS e
    ON c.code = e.code AND p.year = e.year;
# Out:
#     code             local_name                     region  year  \
# 0    AFG  Afganistan/Afqanestan  Southern and Central Asia  2010
# 1    AFG  Afganistan/Afqanestan  Southern and Central Asia  2015
# 2    AGO                 Angola             Central Africa  2010
# 3    AGO                 Angola             Central Africa  2015
# 4    ALB              Shqiperia            Southern Europe  2010
# ..   ...                    ...                        ...   ...
# 365  ZAF           South Africa            Southern Africa  2015
# 366  ZMB                 Zambia             Eastern Africa  2010
# 367  ZMB                 Zambia             Eastern Africa  2015
# 368  ZWE               Zimbabwe             Eastern Africa  2010
# 369  ZWE               Zimbabwe             Eastern Africa  2015
#
#      fertility_rate  unemployment_rate
# 0             5.746                NaN
# 1             4.653                NaN
# 2             6.416                NaN
# 3             5.996                NaN
# 4             1.663              14.00
# ..              ...                ...
# 365           2.339              25.35
# 366           5.687                NaN
# 367           5.284                NaN
# 368           4.048                NaN
# 369           3.856                NaN
#
# [370 rows x 6 columns]

# %% [markdown]
# Countries and their languages, officials or not.

# %%
SELECT local_name AS country, continent,l.name AS language, official
  FROM world.countries AS c
  JOIN world.languages AS l
    USING (code);
# Out:
#                    country continent  language  official
# 0    Afganistan/Afqanestan      Asia      Dari      True
# 1    Afganistan/Afqanestan      Asia    Pashto      True
# 2    Afganistan/Afqanestan      Asia    Turkic     False
# 3    Afganistan/Afqanestan      Asia     Other     False
# 4                Shqiperia    Europe  Albanian      True
# ..                     ...       ...       ...       ...
# 909               Zimbabwe    Africa     Sotho      True
# 910               Zimbabwe    Africa     Tonga      True
# 911               Zimbabwe    Africa    Tswana      True
# 912               Zimbabwe    Africa     Venda      True
# 913               Zimbabwe    Africa     Xhosa      True
#
# [914 rows x 4 columns]

# %% [markdown]
# Percentage increase in population from 2010 to 2015 for each country

# %%
SELECT p1.country_code,
       p1.size AS size2010, 
       p2.size AS size2015,
       ((p2.size - p1.size)/p1.size * 100.0)  AS growth_perc
FROM world.populations AS p1
  INNER JOIN world.populations AS p2
    ON p1.country_code = p2.country_code
        AND p1.year = p2.year - 5;
# Out:
#     country_code  size2010    size2015  growth_perc
# 0            ABW    101597    103889.0     2.255972
# 1            AFG  27962208  32526562.0    16.323297
# 2            AGO  21219954  25021974.0    17.917192
# 3            ALB   2913021   2889167.0    -0.818875
# 4            AND     84419     70473.0   -16.519977
# ..           ...       ...         ...          ...
# 212          XKX   1775680   1801800.0     1.470986
# 213          YEM  23591972  26832216.0    13.734519
# 214          ZAF  50979432  55011976.0     7.910139
# 215          ZMB  13917439  16211767.0    16.485274
# 216          ZWE  13973897  15602751.0    11.656405
#
# [217 rows x 4 columns]

# %% [markdown]
# Here we wanted to look at countries surface’s area not as raw data, but instead as being in different categories or groups. Three categories were created to better understand countries sizes: Large (>2 million), Medium (>350.000) and Small (<350.000).

# %%
SELECT local_name, continent, code, surface_area,
    CASE WHEN surface_area > 2000000 THEN 'large'
        WHEN surface_area > 350000 THEN 'medium'
        ELSE 'small' END
        AS geosize_group
FROM world.countries;
# Out:
#                               local_name      continent code  surface_area  \
# 0                  Afganistan/Afqanestan           Asia  AFG      652090.0
# 1                              Nederland         Europe  NLD       41526.0
# 2                              Shqiperia         Europe  ALB       28748.0
# 3                     Al-Jazair/Algerie         Africa  DZA     2381740.0
# 4                          Amerika Samoa        Oceania  ASM         199.0
# ..                                   ...            ...  ...           ...
# 201                                Eesti         Europe  EST       45227.0
# 202                        United States  North America  USA     9363520.0
# 203  Virgin Islands of the United States  North America  VIR         347.0
# 204                             Zimbabwe         Africa  ZWE      390757.0
# 205                             Filastin           Asia  PSE        6257.0
#
#     geosize_group
# 0          medium
# 1           small
# 2           small
# 3           large
# 4           small
# ..            ...
# 201         small
# 202         large
# 203         small
# 204        medium
# 205         small
#
# [206 rows x 5 columns]

# %% [markdown]
# Relationship between the size of a country in terms of surface area and in terms of population using grouping fields

# %%
SELECT country_code, size,
  CASE WHEN size > 50000000
            THEN 'large'
       WHEN size > 1000000
            THEN 'medium'
       ELSE 'small' END
       AS popsize_group      
FROM world.populations
WHERE year = 2015;
# Out:
#     country_code        size popsize_group
# 0            ABW    103889.0         small
# 1            AFG  32526562.0        medium
# 2            AGO  25021974.0        medium
# 3            ALB   2889167.0        medium
# 4            AND     70473.0         small
# ..           ...         ...           ...
# 212          XKX   1801800.0        medium
# 213          YEM  26832216.0        medium
# 214          ZAF  55011976.0         large
# 215          ZMB  16211767.0        medium
# 216          ZWE  15602751.0        medium
#
# [217 rows x 3 columns]

# %% [markdown]
# Gross domestic product (GDP) per capita by country in 2010

# %%
SELECT local_name, region, gdp_percapita
FROM world.countries AS c
  LEFT JOIN world.economies AS e
    USING (code)
WHERE year = 2010;
# Out:
#                              local_name                     region  \
# 0                 Afganistan/Afqanestan  Southern and Central Asia
# 1                                Angola             Central Africa
# 2                             Shqiperia            Southern Europe
# 3    Al-Imarat al-´Arabiya al-Muttahida                Middle East
# 4                             Argentina              South America
# ..                                  ...                        ...
# 180                               Samoa                  Polynesia
# 181                            Al-Yaman                Middle East
# 182                        South Africa            Southern Africa
# 183                              Zambia             Eastern Africa
# 184                            Zimbabwe             Eastern Africa
#
#      gdp_percapita
# 0          539.667
# 1         3599.270
# 2         4098.130
# 3        34628.630
# 4        10412.950
# ..             ...
# 180       3434.100
# 181       1266.790
# 182       7361.940
# 183       1456.160
# 184        765.418
#
# [185 rows x 3 columns]

# %% [markdown]
# Top 20 countries with highest GDP in 2010

# %%
SELECT local_name, region, gdp_percapita
FROM world.countries AS c
  LEFT JOIN world.economies AS e
    USING (code)
WHERE year = 2010
ORDER BY gdp_percapita DESC
LIMIT 20;
# Out:
#                                local_name                     region  \
# 0                   Luxembourg/Letzebuerg             Western Europe
# 1                                   Norge           Nordic Countries
# 2                                   Qatar                Middle East
# 3          Schweiz/Suisse/Svizzera/Svizra             Western Europe
# 4                              San Marino            Southern Europe
# 5                                 Danmark           Nordic Countries
# 6                               Australia  Australia and New Zealand
# 7                                 Sverige           Nordic Countries
# 8                             Macau/Aomen               Eastern Asia
# 9                               Nederland             Western Europe
# 10                           Ireland/Eire            British Islands
# 11                          United States              North America
# 12                                 Canada              North America
# 13                             Osterreich             Western Europe
# 14  Singapore/Singapura/Xinjiapo/Singapur             Southeast Asia
# 15                                  Suomi           Nordic Countries
# 16                        Belgie/Belgique             Western Europe
# 17                           Nihon/Nippon               Eastern Asia
# 18                            Deutschland             Western Europe
# 19                                 France             Western Europe
#
#     gdp_percapita
# 0       105573.58
# 1        87309.30
# 2        76413.23
# 3        74570.66
# 4        64631.16
# 5        58177.16
# 6        56362.84
# 7        51869.16
# 8        50921.11
# 9        50433.31
# 10       48439.10
# 11       48310.34
# 12       47512.68
# 13       46757.13
# 14       46569.40
# 15       46391.71
# 16       44691.32
# 17       44673.61
# 18       42641.68
# 19       42249.06

# %% [markdown]
# Bottom 20 countries with lowest GDP in 2010.

# %%
SELECT local_name, region, gdp_percapita
FROM world.countries AS c
  LEFT JOIN world.economies AS e
    USING (code)
WHERE year = 2010
ORDER BY gdp_percapita ASC
LIMIT 20;
# Out:
#                           local_name                     region  gdp_percapita
# 0                   Burundi/Uburundi             Eastern Africa        242.840
# 1   Republique Democratique du Congo             Central Africa        292.955
# 2                            Liberia             Western Africa        341.985
# 3                        YeItyop´iya             Eastern Africa        360.829
# 4                              Niger             Western Africa        378.205
# 5                              Ertra             Eastern Africa        395.645
# 6            Madagasikara/Madagascar             Eastern Africa        414.143
# 7                         Mocambique             Eastern Africa        429.948
# 8                             Guinee             Western Africa        435.728
# 9                             Malawi             Eastern Africa        442.765
# 10                      Sierra Leone             Western Africa        448.198
# 11            Centrafrique/Be-Afrika             Central Africa        456.564
# 12                              Togo             Western Africa        497.408
# 13             Afganistan/Afqanestan  Southern and Central Asia        539.667
# 14                        The Gambia             Western Africa        562.200
# 15                    Rwanda/Urwanda             Eastern Africa        577.411
# 16                      Guine-Bissau             Western Africa        582.540
# 17                      Burkina Faso             Western Africa        588.584
# 18                            Uganda             Eastern Africa        594.461
# 19                             Nepal  Southern and Central Asia        595.395

# %% [markdown]
# Top 20 countries with highest GDP in 2015

# %%
SELECT local_name, region, gdp_percapita
FROM world.countries AS c
  LEFT JOIN world.economies AS e
    USING (code)
WHERE year = 2015
AND gdp_percapita IS NOT NULL
ORDER BY gdp_percapita DESC
LIMIT 20;
# Out:
#                                local_name                     region  \
# 0                   Luxembourg/Letzebuerg             Western Europe
# 1          Schweiz/Suisse/Svizzera/Svizra             Western Europe
# 2                                   Norge           Nordic Countries
# 3                             Macau/Aomen               Eastern Asia
# 4                                   Qatar                Middle East
# 5                            Ireland/Eire            British Islands
# 6                           United States              North America
# 7   Singapore/Singapura/Xinjiapo/Singapur             Southeast Asia
# 8                                 Danmark           Nordic Countries
# 9                               Australia  Australia and New Zealand
# 10                                 Island           Nordic Countries
# 11                                Sverige           Nordic Countries
# 12                             San Marino            Southern Europe
# 13                              Nederland             Western Europe
# 14                         United Kingdom            British Islands
# 15                             Osterreich             Western Europe
# 16                                 Canada              North America
# 17                                  Suomi           Nordic Countries
# 18                    Xianggang/Hong Kong               Eastern Asia
# 19                            Deutschland             Western Europe
#
#     gdp_percapita
# 0       100950.49
# 1        81410.02
# 2        74264.43
# 3        70214.90
# 4        68004.02
# 5        60896.18
# 6        56174.94
# 7        53628.76
# 8        53237.28
# 9        51363.90
# 10       50472.94
# 11       50319.11
# 12       46185.02
# 13       44322.83
# 14       43976.42
# 15       43749.55
# 16       43349.62
# 17       42487.05
# 18       42327.59
# 19       41197.41

# %% [markdown]
# Bottom 20 countries with lowest GDP in 2015.

# %%
SELECT local_name, region, gdp_percapita
FROM world.countries AS c
  LEFT JOIN world.economies AS e
    USING (code)
WHERE year = 2015
ORDER BY gdp_percapita ASC
LIMIT 20;
# Out:
#                           local_name                     region  gdp_percapita
# 0                   Burundi/Uburundi             Eastern Africa        318.611
# 1             Centrafrique/Be-Afrika             Central Africa        332.366
# 2                             Malawi             Eastern Africa        353.794
# 3            Madagasikara/Madagascar             Eastern Africa        402.067
# 4                              Niger             Western Africa        406.592
# 5                         The Gambia             Western Africa        448.158
# 6   Republique Democratique du Congo             Central Africa        471.306
# 7                            Liberia             Western Africa        474.357
# 8                         Mocambique             Eastern Africa        529.243
# 9                             Guinee             Western Africa        545.779
# 10                              Togo             Western Africa        569.764
# 11             Afganistan/Afqanestan  Southern and Central Asia        615.091
# 12                      Burkina Faso             Western Africa        619.861
# 13                            Uganda             Eastern Africa        629.536
# 14                      Guine-Bissau             Western Africa        639.508
# 15                      Sierra Leone             Western Africa        718.893
# 16                       YeItyop´iya             Eastern Africa        720.617
# 17                    Rwanda/Urwanda             Eastern Africa        732.372
# 18                    Komori/Comores             Eastern Africa        736.406
# 19                             Ertra             Eastern Africa        741.363

# %% [markdown]
# Average gross domestic product (GDP) per capita by region in 2010.

# %%
SELECT region, ROUND(AVG(gdp_percapita)) AS avg_gdp
FROM world.countries AS c
  LEFT JOIN world.economies AS e
    USING (code)
GROUP BY region, year
HAVING year = 2010
ORDER BY avg_gdp DESC;
# Out:
#                        region  avg_gdp
# 0              Western Europe    58131
# 1            Nordic Countries    57074
# 2               North America    47912
# 3   Australia and New Zealand    44792
# 4             British Islands    43588
# 5                Eastern Asia    26206
# 6             Southern Europe    22926
# 7                 Middle East    18205
# 8            Baltic Countries    12631
# 9                   Caribbean    11413
# 10             Southeast Asia    10547
# 11             Eastern Europe    10095
# 12              South America     7421
# 13            Southern Africa     5052
# 14            Central America     4970
# 15             Central Africa     4797
# 16            Northern Africa     4714
# 17                 Micronesia     4498
# 18                  Polynesia     3451
# 19  Southern and Central Asia     2797
# 20                  Melanesia     2533
# 21             Eastern Africa     1757
# 22             Western Africa      999

# %% [markdown]
# Average gross domestic product (GDP) per capita by region in 2015.

# %%
SELECT region, ROUND(AVG(gdp_percapita)) AS avg_gdp
FROM world.countries AS c
  LEFT JOIN world.economies AS e
    USING (code)
GROUP BY region, year
HAVING year = 2015
ORDER BY avg_gdp DESC;
# Out:
#                        region  avg_gdp
# 0              Western Europe    55680
# 1            Nordic Countries    54156
# 2             British Islands    52436
# 3               North America    49762
# 4   Australia and New Zealand    44322
# 5                Eastern Asia    31046
# 6                 Middle East    18951
# 7             Southern Europe    18947
# 8            Baltic Countries    14995
# 9                   Caribbean    12475
# 10             Southeast Asia    11232
# 11             Eastern Europe     9446
# 12              South America     8264
# 13            Central America     6451
# 14                 Micronesia     6355
# 15            Southern Africa     4456
# 16             Central Africa     3935
# 17                  Polynesia     3718
# 18            Northern Africa     3595
# 19  Southern and Central Asia     3379
# 20                  Melanesia     3086
# 21             Eastern Africa     2208
# 22             Western Africa     1047

# %% [markdown]
# Determine the names of capital cities that are not listed in the cities table. As the cities table contains information about 236 of the world's most populous cities, the result of this query may surprise you in terms of the number of capital cities that do not appear in this list!

# %%
SELECT capital
FROM world.countries
	EXCEPT
SELECT name
FROM world.cities
ORDER BY capital ASC;
# Out:
#               capital
# 0
# 1               Agana
# 2               Amman
# 3           Amsterdam
# 4    Andorra la Vella
# ..                ...
# 131        Wellington
# 132          Windhoek
# 133      Yamoussoukro
# 134    Yaren District
# 135            Zagreb
#
# [136 rows x 1 columns]

# %% [markdown]
# Languages spoken in the Middle East region

# %%
SELECT DISTINCT name
FROM world.languages
WHERE code IN 
  (SELECT code
   FROM world.countries
   WHERE region = 'Middle East')
ORDER BY name ASC;
# Out:
#            name
# 0        Arabic
# 1       Aramaic
# 2      Armenian
# 3   Azerbaijani
# 4         Azeri
# 5       Baluchi
# 6     Bulgarian
# 7    Circassian
# 8       English
# 9         Farsi
# 10     Filipino
# 11       French
# 12     Georgian
# 13        Greek
# 14       Hebrew
# 15        Hindi
# 16       Indian
# 17      Kurdish
# 18        Other
# 19      Persian
# 20     Romanian
# 21      Russian
# 22       Syriac
# 23      Turkish
# 24      Turkmen
# 25  unspecified
# 26         Urdu

# %% [markdown]
# Major capitals cities by area

# %%
SELECT name AS capital_city, country_code, urbanarea_pop
  FROM world.cities
WHERE name IN
  (SELECT capital
  FROM world.countries)
ORDER BY urbanarea_pop DESC;
# Out:
#    capital_city country_code  urbanarea_pop
# 0       Beijing          CHN       21516000
# 1         Dhaka          BGD       14543124
# 2         Tokyo          JPN       13513734
# 3        Moscow          RUS       12197596
# 4         Cairo          EGY       10230350
# ..          ...          ...            ...
# 61        Dakar          SEN        1146053
# 62    Abu Dhabi          ARE        1145000
# 63      Tripoli          LBY        1126000
# 64      Yerevan          ARM        1060138
# 65        Tunis          TUN        1056247
#
# [66 rows x 3 columns]

# %% [markdown]
# Is it Bogotá in the Top 15 of major capitals (by area) of the world?

# %%
SELECT name AS capital_city, country_code, urbanarea_pop
  FROM world.cities
WHERE name IN
  (SELECT capital
  FROM world.countries)
ORDER BY urbanarea_pop DESC
LIMIT 15;
# Out:
#    capital_city country_code  urbanarea_pop
# 0       Beijing          CHN       21516000
# 1         Dhaka          BGD       14543124
# 2         Tokyo          JPN       13513734
# 3        Moscow          RUS       12197596
# 4         Cairo          EGY       10230350
# 5      Kinshasa          COD       10130000
# 6       Jakarta          IDN       10075310
# 7         Seoul          KOR        9995784
# 8   Mexico City          MEX        8974724
# 9          Lima          PER        8852000
# 10       London          GBR        8673713
# 11      Bangkok          THA        8280925
# 12       Tehran          IRN        8154051
# 13       Bogota          COL        7878783
# 14      Baghdad          IRQ        7180889

# %% [markdown]
# Yes, It is. Bogota is the world's 14th largest capital!

# %% [markdown]
# Top 9 countries in terms of number of most populous cities in the world.

# %%
SELECT code, local_name AS country,
  (SELECT COUNT (*)
   FROM world.cities
   WHERE countries.code = cities.country_code) AS populous_cities_num
FROM world.countries
ORDER BY populous_cities_num DESC, country ASC
LIMIT 9;
# Out:
#   code                  country  populous_cities_num
# 0  CHN                 Zhongquo                   36
# 1  IND             Bharat/India                   18
# 2  JPN             Nihon/Nippon                   11
# 3  BRA                   Brasil                   10
# 4  PAK                 Pakistan                    9
# 5  USA            United States                    9
# 6  IDN                Indonesia                    7
# 7  RUS                  Rossija                    7
# 8  KOR  Taehan Minguk (Namhan)                    7

# %% [markdown]
# The countries with the highest inflation in the world in 2015 by continent, and how high it was.

# %%
SELECT local_name, continent, inflation_rate
  FROM world.countries
	INNER JOIN world.economies
	ON countries.code = economies.code
  WHERE year = 2015
    AND inflation_rate IN (
        SELECT MAX(inflation_rate) AS max_inf
        FROM (
             SELECT local_name, continent, inflation_rate
             FROM world.countries
             INNER JOIN world.economies
             ON countries.code = economies.code
             WHERE year = 2015) AS subquery
        GROUP BY continent)
        ORDER BY inflation_rate DESC;
# Out:
#      local_name      continent  inflation_rate
# 0     Venezuela  South America         121.738
# 1      Ukrajina         Europe          48.684
# 2      Al-Yaman           Asia          39.403
# 3        Malawi         Africa          21.858
# 4  Naoero/Nauru        Oceania           9.784
# 5   Haiti/Dayti  North America           7.524

# %% [markdown]
# Top 10 capital cities in Europe and the Americas in terms of a calculated percentage

# %%
SELECT name, country_code, city_proper_pop, metroarea_pop,  
      city_proper_pop / metroarea_pop * 100 AS city_perc
  FROM world.cities
  WHERE name IN
    (SELECT capital
     FROM world.countries
     WHERE (continent = 'Europe'
        OR continent LIKE '%America%'))
       AND metroarea_pop IS NOT NULL
ORDER BY city_perc DESC
LIMIT 10;
# Out:
#          name country_code  city_proper_pop  metroarea_pop  city_perc
# 0        Lima          PER          8852000       10750000  82.344186
# 1      Bogota          COL          7878783        9800000  80.395746
# 2      Moscow          RUS         12197596       16170000  75.433493
# 3      Vienna          AUT          1863881        2600000  71.687728
# 4  Montevideo          URY          1305082        1947604  67.009616
# 5     Caracas          VEN          1943901        2923959  66.481817
# 6        Rome          ITA          2877215        4353775  66.085523
# 7    Brasilia          BRA          2556149        3919864  65.210146
# 8      London          GBR          8673713       13879757  62.491822
# 9    Budapest          HUN          1759407        2927944  60.090184
